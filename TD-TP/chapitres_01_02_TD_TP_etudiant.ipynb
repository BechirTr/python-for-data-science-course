# %% [markdown]
# # Chapitres 1 et 2 — TD et TP
# ## Entraînement au partiel
#
# Variables, conditions et boucles ; fonctions, listes, tuples, dictionnaires et ensembles.
#
# Avant la séance, parcourez les questions et commencez celles que vous savez aborder.
# Notez les points qui vous bloquent : nous les reprendrons ensemble pendant la seconde moitié de la séance.
# Ce travail n'est pas noté.
#
# Vous retrouverez ici les formats que nous préparons pour le partiel : QCM, lecture de code,
# recherche d'erreurs et écriture de programmes.

# %% [markdown]
# ### Quelques habitudes à prendre
#
# - Pour les QCM, choisissez une seule réponse et justifiez-la en une phrase.
# - Pour lire ou corriger du code, prévoyez le résultat sur papier avant de lancer Python.
# - Pour les programmes à écrire, commencez par le pseudocode, rédigez le code, puis faites une trace à la main avant de l'exécuter. Suivez chaque tour de boucle et indiquez ce qui provoque l'arrêt.
#
# Les cellules Markdown servent aux explications et aux tableaux : double-cliquez pour les modifier.
# Les cellules de code servent aux essais. Gardez une trace de vos erreurs et de ce que vous avez changé.
#
# Le notebook utilise uniquement Python 3, sans bibliothèque à installer. Les données sont écrites dans le code ;
# aucune saisie avec `input()` n'est nécessaire. Les tests des programmes à compléter sont laissés en commentaire :
# retirez le `#` quand votre fonction est prête.

# %% [markdown]
# ## A. QCM
#
# Une seule réponse est correcte pour chaque question. Ne vous contentez pas de la lettre :
# expliquez brièvement ce qui vous permet de choisir.

# %% [markdown]
# ### 1. Des valeurs qui évoluent
#
# ```python
# n = 7
# q = n // 2
# n = n + 1
# print(n, q, n % 2)
# ```
#
# Que va-t-on voir à l’écran ?
#
# - **A.** `8 4 0`
# - **B.** `8 3 0`
# - **C.** `7 3 1`
# - **D.** `8 3.5 0`

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 2. Le cas de la frontière
#
# ```python
# note = 10
# if note > 10:
#     print("admis")
# elif note == 10:
#     print("juste")
# else:
#     print("à revoir")
# ```
#
# Quel message est affiché ?
#
# - **A.** `admis`
# - **B.** `admis`, puis `juste`
# - **C.** `juste`
# - **D.** `à revoir`

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 3. Afficher et renvoyer
#
# ```python
# def double(x):
#     print(2 * x)
#
# resultat = double(3)
# print(resultat)
# ```
#
# Quelles sont les deux lignes affichées, dans l’ordre ?
#
# - **A.** `6`, puis `None`
# - **B.** `6`, puis `6`
# - **C.** `3`, puis `6`
# - **D.** `None`, puis `6`

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 4. Ajouter à une liste
#
# ```python
# valeurs = [4, 1]
# resultat = valeurs.append(2)
# print(valeurs, resultat)
# ```
#
# Quel est le résultat ?
#
# - **A.** `[4, 1] [4, 1, 2]`
# - **B.** `[4, 1, 2] 2`
# - **C.** `[4, 1, 2] [4, 1, 2]`
# - **D.** `[4, 1, 2] None`

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 5. Une clé absente
#
# ```python
# scores = {"Ada": 12}
# print(scores.get("Lin", 0))
# print("Lin" in scores)
# ```
#
# Quelles sont les deux lignes affichées ?
#
# - **A.** `0`, puis `True`
# - **B.** `0`, puis `False`
# - **C.** `None`, puis `False`
# - **D.** Une erreur `KeyError`, puis le programme s’arrête.

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 6. Remplacer une valeur dans un tuple
#
# ```python
# position = (2, 5)
# position[0] = 3
# print(position)
# ```
#
# Que se passe-t-il ?
#
# - **A.** Le programme affiche `(3, 5)`.
# - **B.** Le programme affiche `[3, 5]`.
# - **C.** Une erreur `TypeError` se produit avant le `print`.
# - **D.** Le programme affiche `(2, 5)` sans erreur.

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 7. Choisir une collection
#
# On veut retenir les identifiants déjà rencontrés, sans doublons, et tester si un identifiant a déjà été vu. L’ordre n’a pas d’importance. Quelle structure convient le mieux ?
#
# - **A.** Un ensemble (`set`).
# - **B.** Un entier (`int`).
# - **C.** Un tuple contenant toujours une seule valeur.
# - **D.** Une chaîne obtenue en collant tous les identifiants.

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ### 8. Convertir une chaîne
#
# ```python
# nombre = int("3.5")
# print(nombre)
# ```
#
# Quel est le comportement de ce programme ?
#
# - **A.** Il affiche `3`.
# - **B.** Il affiche `3.5`.
# - **C.** Il affiche la chaîne `"3.5"`.
# - **D.** Il lève une erreur `ValueError` avant l’affichage.

# %% [markdown]
# **Réponse :** …
#
# **Pourquoi :** …

# %% [markdown]
# ## B. Comprendre un programme
#
# Les deux programmes suivants sont corrects. Cherchez ce qu'ils font avant de les exécuter.

# %% [markdown]
# ### Exercice 1 — Que compte cette fonction ?
#
# ```python
# def bilan(valeurs):
#     total = 0
#     nombre = 0
#     for valeur in valeurs:
#         if valeur >= 5:
#             total = total + valeur
#             nombre = nombre + 1
#     return total, nombre
#
# s, n = bilan([4, 7, 5, 2])
# print(s, n)
# ```
#
# 1. Expliquez le rôle de `total` et de `nombre`.
# 2. Complétez la trace. Les valeurs demandées sont celles de la fin du tour.
# 3. Donnez le type et la valeur de ce que renvoie `bilan([4, 7, 5, 2])`, puis la ligne affichée.
# 4. Que renvoie `bilan([])` ? Justifiez sans exécuter le code.

# %% [markdown]
# **Rôle des deux variables :** …
#
# | Étape | `valeur` | `valeur >= 5` | `total` après le tour | `nombre` après le tour |
# |---|---|---|---|---|
# | Initialisation | — | — | 0 | 0 |
# | Tour 1 | 4 | … | … | … |
# | Tour 2 | 7 | … | … | … |
# | Tour 3 | 5 | … | … | … |
# | Tour 4 | 2 | … | … | … |
#
# **Pourquoi la boucle s'arrête :** …
#
# **Valeur renvoyée et type :** …
#
# **Affichage prévu :** …
#
# **Avec une liste vide :** …

# %%
# Exécutez après avoir rempli le tableau.
def bilan(valeurs):
    total = 0
    nombre = 0
    for valeur in valeurs:
        if valeur >= 5:
            total = total + valeur
            nombre = nombre + 1
    return total, nombre

s, n = bilan([4, 7, 5, 2])
print(s, n)

# %% [markdown]
# ### Exercice 2 — Quelles listes sont modifiées ?
#
# ```python
# def ajouter_bonus(notes):
#     notes.append(10)
#     notes = notes + [20]
#     return notes
#
# depart = [6, 8]
# copie = depart.copy()
# resultat = ajouter_bonus(depart)
# print(depart)
# print(copie)
# print(resultat)
# ```
#
# 1. Pendant l'appel, suivez les valeurs désignées par `depart`, `copie` et le paramètre local `notes`.
# 2. Écrivez les trois lignes affichées, dans l'ordre.
# 3. Pourquoi l'ajout de `10` et celui de `20` n'ont-ils pas le même effet sur `depart` ?
# 4. Si on remplace seulement `copie = depart.copy()` par `copie = depart`, que devient la deuxième ligne affichée ?

# %% [markdown]
# | Moment pendant l'appel | `depart` | `copie` | `notes` |
# |---|---|---|---|
# | À l'entrée dans la fonction | … | … | … |
# | Après `notes.append(10)` | … | … | … |
# | Après `notes = notes + [20]` | … | … | … |
#
# **Les trois lignes affichées :**
#
# ```text
# …
# …
# …
# ```
#
# **Explication :** …
#
# **Avec `copie = depart` :** …

# %%
# Comparez la sortie à votre prévision.
def ajouter_bonus(notes):
    notes.append(10)
    notes = notes + [20]
    return notes

depart = [6, 8]
copie = depart.copy()
resultat = ajouter_bonus(depart)
print(depart)
print(copie)
print(resultat)

# %% [markdown]
# ## C. Trouver et corriger les erreurs
#
# Pour chaque programme, expliquez la cause du problème, puis écrivez une version corrigée dans la cellule prévue.
# Les versions erronées sont présentées en texte : recopiez votre correction dans la cellule de code.

# %% [markdown]
# ### Exercice 3 — Le compteur s'arrête trop tôt
#
# On veut que `compter_e(s)` renvoie le nombre de lettres `"e"` minuscules, sans accent.
# La chaîne vide doit donner `0`. Ainsi, `compter_e("eleve")` doit renvoyer `3`.
#
# ```python
# def compter_e(s):
#     i = 0
#     nombre = 0
#     while i <= len(s):
#         if s[i] == "e":
#             nombre = nombre + 1
#         i = i + 1
#         return nombre
# ```
#
# 1. Que renvoie réellement cette version pour `"eleve"` ? Jusqu'où l'exécution va-t-elle ?
# 2. Il y a deux erreurs. Repérez-les et expliquez pourquoi corriger seulement l'une ne suffit pas.
# 3. Corrigez la fonction en gardant une boucle `while`, sans utiliser `count()`.
# 4. Faites la trace de votre version pour `"eleve"`, puis complétez et essayez les tests.

# %% [markdown]
# **Résultat de la version erronée pour `"eleve"` :** …
#
# | Emplacement de l'erreur | Conséquence | Correction proposée |
# |---|---|---|
# | … | … | … |
# | … | … | … |
#
# **Si on ne corrige qu'une erreur :** …

# %%
# Écrivez ici la fonction compter_e corrigée.

# %% [markdown]
# **Trace à la main, avant exécution — `s = "eleve"`**
#
# Au départ : `i = 0`, `nombre = 0`. Relevez aussi le dernier test, quand on sort de la boucle.
#
# | `i` avant le test | Condition du `while` | Caractère lu (s'il y en a un) | `nombre` après le tour | `i` après le tour |
# |---|---|---|---|---|
# | 0 | … | … | … | … |
# | 1 | … | … | … | … |
# | 2 | … | … | … | … |
# | 3 | … | … | … | … |
# | 4 | … | … | … | … |
# | 5 | … | … | … | … |
#
# **Valeur renvoyée :** …

# %% [markdown]
# | `s` | Résultat attendu |
# |---|---|
# | `"eleve"` | 3 |
# | `""` | … |
# | `"e"` | … |
# | `"Eee"` | … |
# | `"été"` | … |

# %%
# Décommentez et remplacez les ... par les résultats de votre tableau.
# assert compter_e("eleve") == 3
# assert compter_e("") == ...
# assert compter_e("e") == ...
# assert compter_e("Eee") == ...
# assert compter_e("été") == ...

# %% [markdown]
# ### Exercice 4 — Compter les mots
#
# La fonction `frequences(mots)` doit **renvoyer un dictionnaire** donnant le nombre d'apparitions de chaque mot.
# Elle reçoit une liste de chaînes et ne doit pas la modifier. On distingue les majuscules des minuscules :
# `"Oui"` et `"oui"` sont deux clés différentes.
#
# ```python
# def frequences(mots):
#     compte = {}
#     for mot in mots:
#         compte[mot] = compte[mot] + 1
#     print(compte)
# ```
#
# 1. Quelle est la première erreur lors de l'appel `frequences(["oui", "non", "oui"])` ? Expliquez sa cause.
# 2. Supposons cette première erreur corrigée. Pourquoi `resultat = frequences(["oui"])` ne récupère-t-il toujours pas le dictionnaire ?
# 3. Corrigez les deux problèmes. Vous pouvez utiliser `get()` ou un test d'appartenance au dictionnaire.
# 4. Tracez l'appel sur `["oui", "non", "oui"]` avant de vérifier votre fonction avec Python.

# %% [markdown]
# **Première erreur et ligne concernée :** …
#
# **Ce que contient `resultat` après la première correction :** …
#
# **Les deux changements à faire :** …

# %%
# Écrivez ici la fonction frequences corrigée.

# %% [markdown]
# **Trace de la correction — `mots = ["oui", "non", "oui"]`**
#
# | Étape | `mot` | Ancien nombre d'apparitions (0 si absent) | `compte` après le tour |
# |---|---|---|---|
# | Initialisation | — | — | `{}` |
# | Tour 1 | `"oui"` | … | … |
# | Tour 2 | `"non"` | … | … |
# | Tour 3 | `"oui"` | … | … |
#
# **Arrêt de la boucle et valeur renvoyée :** …
#
# | `mots` | Résultat attendu |
# |---|---|
# | `[]` | … |
# | `["oui"]` | … |
# | `["oui", "non", "oui"]` | … |
# | `["Oui", "oui"]` | … |

# %%
# Décommentez et complétez avec les dictionnaires attendus.
# assert frequences([]) == ...
# assert frequences(["oui"]) == ...
# assert frequences(["oui", "non", "oui"]) == ...
# assert frequences(["Oui", "oui"]) == ...

# Vérifiez aussi que la liste passée en argument n'a pas été modifiée.

# %% [markdown]
# ## D. Écrire un programme
#
# Pour les deux exercices suivants, rendez votre démarche visible : un pseudocode en français,
# le programme Python, puis une trace manuelle et quelques tests. Dans le pseudocode, faites apparaître
# les initialisations, les conditions, les boucles et les valeurs renvoyées.

# %% [markdown]
# ### Exercice 5 — Chercher deux caractères consécutifs
#
# Écrivez `contient_deux(s, motif)`. La fonction reçoit deux chaînes et renvoie `True` si les deux caractères
# de `motif` apparaissent côte à côte et dans le même ordre dans `s`, sinon `False`.
# On garantit que `motif` contient exactement deux caractères ; vous n'avez pas à traiter les autres longueurs.
#
# Par exemple, `contient_deux("papa", "ap")` renvoie `True`, mais `contient_deux("abc", "ac")` renvoie `False`.
# Si `s` contient moins de deux caractères, le résultat est `False`. Les comparaisons distinguent majuscules et minuscules.
#
# Utilisez une boucle `for` avec des indices et comparez les caractères un par un.
# Pour cet exercice, n'utilisez ni recherche avec `in`, ni `find()`, `index()`, `count()`, `startswith()`,
# ni découpage de chaîne par tranche. Le `in` de la syntaxe `for i in range(...)` reste bien sûr autorisé.
#
# Avant de coder, déterminez le dernier indice où une comparaison de deux caractères reste possible.

# %% [markdown]
# **Dernier indice de départ possible, en fonction de `len(s)` :** …
#
# **Pseudocode :**
#
# ```text
# FONCTION contient_deux(s, motif)
#     ...
# FIN FONCTION
# ```

# %%
# Écrivez la fonction contient_deux à partir de votre pseudocode.

# %% [markdown]
# **Avant de lancer le code : tracez `contient_deux("papa", "ap")`.**
#
# Adaptez le nombre de lignes à votre programme. Si votre fonction rencontre un `return`, arrêtez la trace à cet endroit.
# Dans la colonne « paire », notez les deux caractères voisins à comparer, même si Python peut éviter
# la seconde comparaison lorsque la première est déjà fausse.
#
# | Tour exécuté | `i` | Paire à comparer | Correspond au motif ? | Suite de l'exécution |
# |---|---|---|---|---|
# | 1 | … | … | … | … |
# | 2 | … | … | … | … |
# | … | … | … | … | … |
#
# **Valeur renvoyée et raison de l'arrêt :** …
#
# **Combien de tours pour `contient_deux("a", "ap")` ? Quel résultat ?** …

# %% [markdown]
# Complétez les résultats attendus, puis ajoutez un cas pour vérifier la distinction entre majuscules et minuscules.
#
# | `s` | `motif` | Résultat attendu |
# |---|---|---|
# | `"papa"` | `"ap"` | `True` |
# | `"abc"` | `"ab"` | … |
# | `"abc"` | `"bc"` | … |
# | `"abc"` | `"ac"` | … |
# | `""` | `"ab"` | … |
# | `"a"` | `"ab"` | … |
# | `"aa"` | `"aa"` | … |
# | … | … | … |

# %%
# Décommentez une fois la trace terminée, puis complétez les résultats attendus.
# assert contient_deux("papa", "ap") == True
# assert contient_deux("abc", "ab") == ...
# assert contient_deux("abc", "bc") == ...
# assert contient_deux("abc", "ac") == ...
# assert contient_deux("", "ab") == ...
# assert contient_deux("a", "ab") == ...
# assert contient_deux("aa", "aa") == ...

# Ajoutez votre test sur les majuscules et minuscules.

# %% [markdown]
# ### Exercice 6 — Nettoyer une liste de noms
#
# Écrivez `nettoyer_noms(noms)`. L'argument est une liste de chaînes. La fonction renvoie une nouvelle liste qui respecte ces règles :
#
# - retirer les espaces au début et à la fin de chaque nom avec `strip()` ;
# - passer le nom en minuscules avec `lower()` ;
# - ignorer les chaînes devenues vides ;
# - ne garder qu'une apparition de chaque nom nettoyé, dans l'ordre de sa première apparition.
#
# La liste reçue en argument doit rester intacte. Il n'y a pas d'autre transformation à faire :
# les espaces à l'intérieur d'un nom et les accents sont conservés.
#
# ```text
# Entrée   : [" Ali ", "", "Lina", "ali", "  ", " LINA ", "Sami"]
# Résultat : ["ali", "lina", "sami"]
# ```
#
# Utilisez une boucle explicite, une liste pour construire le résultat et un ensemble pour mémoriser
# les noms déjà retenus. Évitez de convertir directement un ensemble en liste : cela ne permet pas de conserver l'ordre demandé.

# %% [markdown]
# **Rôle de la liste et de l'ensemble dans votre solution :** …
#
# **Pseudocode :**
#
# ```text
# FONCTION nettoyer_noms(noms)
#     ...
# FIN FONCTION
# ```

# %%
# Écrivez la fonction nettoyer_noms.

# %% [markdown]
# **Trace à la main — `noms = [" Ali ", "", "Lina", "ali"]`**
#
# Au départ, la liste de résultat et l'ensemble des noms vus sont vides.
# Notez le contenu de ces collections après chaque tour. L'ordre d'écriture des éléments de l'ensemble n'a pas d'importance.
#
# | Tour | `nom_brut` | Nom nettoyé | Retenu ? Pourquoi ? | Ensemble après le tour | Liste après le tour |
# |---|---|---|---|---|---|
# | 1 | `" Ali "` | … | … | … | … |
# | 2 | `""` | … | … | … | … |
# | 3 | `"Lina"` | … | … | … | … |
# | 4 | `"ali"` | … | … | … | … |
#
# **Quand la boucle s'arrête-t-elle et que renvoie la fonction ?** …
#
# **Pourquoi la liste d'origine reste-t-elle intacte ?** …

# %% [markdown]
# Complétez les résultats attendus. Ajoutez ensuite un test qui vérifierait une règle encore peu couverte.
#
# | `noms` | Résultat attendu |
# |---|---|
# | `[]` | … |
# | `["", "   "]` | … |
# | `["Ali", " ALI ", "ali"]` | … |
# | `["Zoe", "Ali", "Zoe"]` | … |
# | `[" Ali ", "", "Lina", "ali", "  ", " LINA ", "Sami"]` | `["ali", "lina", "sami"]` |
# | … | … |

# %%
# Décommentez et complétez après avoir rempli le tableau.
# assert nettoyer_noms([]) == ...
# assert nettoyer_noms(["", "   "]) == ...
# assert nettoyer_noms(["Ali", " ALI ", "ali"]) == ...
# assert nettoyer_noms(["Zoe", "Ali", "Zoe"]) == ...

# noms_test = [" Ali ", "", "Lina", "ali", "  ", " LINA ", "Sami"]
# avant = noms_test.copy()
# resultat = nettoyer_noms(noms_test)
# assert resultat == ["ali", "lina", "sami"]
# assert noms_test == avant

# Ajoutez votre test personnel.

# %% [markdown]
# ## Auto-évaluation
#
# Après la séance, cochez une case par ligne en pensant à ce que vous sauriez refaire sans regarder la correction.
#
# | Je sais… | Seul·e | Avec un coup de pouce | À reprendre |
# |---|---|---|---|
# | prévoir une valeur, un type ou un affichage ; | ☐ | ☐ | ☐ |
# | suivre une boucle et expliquer son arrêt ; | ☐ | ☐ | ☐ |
# | distinguer `print` et `return`, et placer le `return` au bon endroit ; | ☐ | ☐ | ☐ |
# | expliquer la différence entre une copie et deux noms pour une même liste ; | ☐ | ☐ | ☐ |
# | utiliser un dictionnaire pour compter et un ensemble pour repérer les doublons ; | ☐ | ☐ | ☐ |
# | passer d'un énoncé à un pseudocode, puis à un programme ; | ☐ | ☐ | ☐ |
# | choisir un test ordinaire et un cas limite pour vérifier une fonction. | ☐ | ☐ | ☐ |
#
# **Une erreur que je comprends mieux maintenant :** …
#
# **Un exercice que je veux refaire sans aide :** …
#
# **Une question à reprendre ensemble :** …
